# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from PIL import Image
import bm3d

# %%
def minMaxNormalized(img):
    return cv2.normalize(img, None, 0, 1, cv2.NORM_MINMAX,dtype=cv2.CV_32F)

# %%
def colorSeparator(image_rgb):
    r = image_rgb[:,:,0]
    g = image_rgb[:,:,1]
    b = image_rgb[:,:,2]
    return r, g, b

# %%
def high_boost(img, low_contrast, A):
    return ((A-1)*low_contrast + img)

# %%
# return red, green and blue freq. domain
def to_frequencyDomainGray(gray_img):
    gray_img     = minMaxNormalized(gray_img)
    norm_fft       = np.fft.fft2(gray_img)
    norm_fft_shift = np.fft.fftshift(norm_fft)
    return norm_fft_shift

def to_frequencyDomain(image): 
    r,g,b = colorSeparator(image)
    r_fftshft = to_frequencyDomainGray(r)
    b_fftshft = to_frequencyDomainGray(b)
    g_fftshft = to_frequencyDomainGray(g)
    return r_fftshft, b_fftshft, g_fftshft

def magnitudeLog(img):
    mag = np.sqrt(img.real ** 2 + img.imag ** 2)
    return np.log1p(mag)

# %%
def to_spatialDomain(image):
    image_ishift = np.fft.ifftshift(image)
    image_ifft   = np.fft.ifft2(image_ishift)
    image_real   = np.abs(image_ifft)
    # denormlized  = image * 255
    return image_real

# %%
def reduceSaltAndPeperNoise(image, kernel=3):
    median_filtered = cv2.medianBlur(image, kernel)
    return median_filtered

# %%
#use bm3d method. before use this function make sure install package. (pip3 install bm3d)
def reduceGaussianNoise(image, sigma=20/255):
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    R, G, B = cv2.split(image_rgb)

    R_denoised = bm3d.bm3d(R / 255.0, sigma) * 255
    G_denoised = bm3d.bm3d(G / 255.0, sigma) * 255
    B_denoised = bm3d.bm3d(B / 255.0, sigma) * 255

    image_denoised = cv2.merge((R_denoised, G_denoised, B_denoised))
    image_denoised = np.clip(image_denoised, 0, 255).astype(np.uint8)

    image_denoised = cv2.cvtColor(image_denoised, cv2.COLOR_RGB2BGR)
    
    return image_denoised

# %%
#periodic noise...

# %%
# for one type of periodic noise. which type?
def NotchFilter(shape, radius, center_x, center_y):
    dimention1, dimention2 = shape
    mask = np.zeros((dimention1, dimention2, 2))

    for i in range(0, dimention1):
        for item in range(0, dimention2):
            radius_hat1 = np.sqrt((i - center_x) ** 2 + (item - center_y) ** 2)
            radius_hat2 = np.sqrt((i - dimention1 + center_x) ** 2 + (item - dimention2 + center_y) ** 2)

            if radius_hat1 <= radius or radius_hat2 <= radius:
                mask[i, item] = 0.0
            else:
                mask[i, item] = 1.0
    return mask

# %%
# maybe we need this function. negative of above function. return just periodic noise
def negetiveNotchFilter(shape, radius, center_x, center_y):
    dimention1, dimention2 = shape
    mask = np.zeros((dimention1, dimention2, 2))

    for i in range(0, dimention1):
        for item in range(0, dimention2):
            radius_hat1 = np.sqrt((i - center_x) ** 2 + (item - center_y) ** 2)
            radius_hat2 = np.sqrt((i - dimention1 + center_x) ** 2 + (item - dimention2 + center_y) ** 2)

            if radius_hat1 <= radius or radius_hat2 <= radius:
                mask[i, item] = 1.0
            else:
                mask[i, item] = 0.0
    return mask

# %%
# maybe we need this function
def psnr(original_image, reconstructed_image):
    original_image      = original_image.astype(np.float64)
    reconstructed_image = reconstructed_image.astype(np.float64)

    mse = np.mean((original_image - reconstructed_image) ** 2)

    if mse == 0:
        return float('inf')

    max_pixel_value = 255 
    psnr = 10 * np.log10((max_pixel_value ** 2) / mse)
    return psnr

# %%
#input: BGR image
def equalizeHistForColorImages (img):
    img_yuv = cv2.cvtColor(img, cv2.COLOR_BGR2YUV)
    img_yuv[:, :, 0] = cv2.equalizeHist(img_yuv[:, :, 0])
    return cv2.cvtColor(img_yuv, cv2.COLOR_YUV2BGR)

# %%
from scipy.ndimage import gaussian_filter

def detect_and_remove_periodic_noise(image_path, threshold_factor=10, radius=10):
    # 1. بارگذاری تصویر و تبدیل به سطح خاکستری
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    
    # 2. انجام FFT و محاسبه طیف فرکانسی
    f = np.fft.fft2(img)
    fshift = np.fft.fftshift(f)  # انتقال صفر فرکانس به مرکز تصویر
    magnitude_spectrum = np.log(1 + np.abs(fshift))  # نمایش طیف
    
    # 3. شناسایی خودکار نویز پریودیک
    blurred_spectrum = gaussian_filter(magnitude_spectrum, sigma=3)  # حذف نویزهای کوچک‌تر
    threshold = np.mean(blurred_spectrum) + threshold_factor * np.std(blurred_spectrum)  # تنظیم آستانه

    # پیدا کردن نقاط نویز (نقاطی که روشن‌تر از مقدار آستانه هستند)
    noisy_points = np.argwhere(magnitude_spectrum > threshold)
    
    # 4. ایجاد ماسک برای حذف نویز
    rows, cols = img.shape
    mask = np.ones((rows, cols), np.uint8)
    
    # نقاط نویزی را حذف کن (با اعمال دایره‌های سیاه)
    for (x, y) in noisy_points:
        cv2.circle(mask, (y, x), radius, 0, -1)  # حذف نقاط نویزی
    
    # 5. اعمال ماسک بر روی طیف فرکانسی
    fshift_filtered = fshift * mask
    
    # 6. انجام تبدیل معکوس فوریه
    f_ishift = np.fft.ifftshift(fshift_filtered)
    img_filtered = np.fft.ifft2(f_ishift)
    img_filtered = np.abs(img_filtered)  # مقدار مطلق برای نمایش صحیح

    # 7. نمایش نتایج
    plt.figure(figsize=(12, 6))
    
    plt.subplot(1, 3, 1)
    plt.title("Original Image")
    plt.imshow(img, cmap="gray")
    
    plt.subplot(1, 3, 2)
    plt.title("Frequency Spectrum")
    plt.imshow(magnitude_spectrum, cmap="gray")
    
    plt.subplot(1, 3, 3)
    plt.title("Filtered Image")
    plt.imshow(img_filtered, cmap="gray")
    
    plt.show()

# اجرای کد روی یک تصویر
# detect_and_remove_periodic_noise("your_image.jpg")

# %%
detect_and_remove_periodic_noise('cardboard3.jpg', 40)

# %%
without_pre = cv2.imread('without/cardboard1.jpg')

b, g, r = cv2.split(without_pre)

# b_fre = to_frequencyDomain(b)
# g_fre = to_frequencyDomain(g)
# r_fre = to_frequencyDomain(r)

# r_fre, g_fre, b_fre = to_frequencyDomain(without_pre)


r_fre = np.fft.fft2(r)
r_fre = np.fft.fftshift(r_fre)

g_fre = np.fft.fft2(r)
g_fre = np.fft.fftshift(g_fre)

b_fre = np.fft.fft2(r)
b_fre = np.fft.fftshift(b_fre)

# r_fre.dtype

plt.Figure(figsize=(12, 6))

plt.subplot(3, 2, 1)
plt.title('r original')
plt.axis('off')
plt.imshow(r, cmap='Reds')

plt.subplot(3, 2, 2)
plt.title('r fre')
plt.axis('off')
plt.imshow(np.log(magnitudeLog(r_fre)), cmap='gray')

plt.subplot(3, 2, 3)
plt.title('g original')
plt.axis('off')
plt.imshow(g, cmap='Greens')

plt.subplot(3, 2, 4)
plt.title('g original')
plt.axis('off')
plt.imshow(np.log(magnitudeLog(g_fre)), cmap='gray')

plt.subplot(3, 2, 5)
plt.title('b original')
plt.axis('off')
plt.imshow(b, cmap='Blues')

plt.subplot(3, 2, 6)
plt.title('b original')
plt.axis('off')
plt.imshow(np.log(magnitudeLog(b_fre)), cmap='gray')

# %%
with_pre = cv2.imread('cardboard1.jpg')

b_pre, g_pre, r_pre = cv2.split(with_pre)

# b_fre = to_frequencyDomain(b)
# g_fre = to_frequencyDomain(g)
# r_fre = to_frequencyDomain(r)

# r_fre, g_fre, b_fre = to_frequencyDomain(without_pre)


r_pre_fre = np.fft.fft2(r_pre)
r_pre_fre = np.fft.fftshift(r_pre_fre)

g_pre_fre = np.fft.fft2(r_pre)
g_pre_fre = np.fft.fftshift(g_pre_fre)

b_pre_fre = np.fft.fft2(r_pre)
b_pre_fre = np.fft.fftshift(b_pre_fre)

# r_fre.dtype

plt.Figure(figsize=(12, 6))

plt.subplot(3, 2, 1)
plt.title('r original')
plt.axis('off')
plt.imshow(r, cmap='Reds')

plt.subplot(3, 2, 2)
plt.title('r fre')
plt.axis('off')
plt.imshow(np.log(magnitudeLog(r_fre)), cmap='gray')

plt.subplot(3, 2, 3)
plt.title('g original')
plt.axis('off')
plt.imshow(g, cmap='Greens')

plt.subplot(3, 2, 4)
plt.title('g original')
plt.axis('off')
plt.imshow(np.log(magnitudeLog(g_fre)), cmap='gray')

plt.subplot(3, 2, 5)
plt.title('b original')
plt.axis('off')
plt.imshow(b, cmap='Blues')

plt.subplot(3, 2, 6)
plt.title('b original')
plt.axis('off')
plt.imshow(np.log(magnitudeLog(b_fre)), cmap='gray')

# %%
plt.Figure(figsize=(12, 6))

plt.subplot(3, 2, 1)
plt.title('r original')
plt.axis('off')
plt.imshow(np.log(magnitudeLog(r_fre)), cmap='gray')

plt.subplot(3, 2, 2)
plt.title('g original')
plt.axis('off')
plt.imshow(np.log(magnitudeLog(g_fre)), cmap='gray')

plt.subplot(3, 2, 3)
plt.title('b original')
plt.axis('off')
plt.imshow(np.log(magnitudeLog(b_fre)), cmap='gray')

plt.subplot(3, 2, 4)
plt.title('r noisy')
plt.axis('off')
plt.imshow(np.log(magnitudeLog(r_pre_fre)), cmap='gray')

plt.subplot(3, 2, 5)
plt.title('g noisy')
plt.axis('off')
plt.imshow(np.log(magnitudeLog(g_pre_fre)), cmap='gray')

plt.subplot(3, 2, 6)
plt.title('b noisy')
plt.axis('off')
plt.imshow(np.log(magnitudeLog(b_pre_fre)), cmap='gray')
